# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load earthquake data
earthquake_data = pd.read_csv('all_month.csv')
earthquake_data
# Out:
# C:\Users\kater\AppData\Local\Temp\ipykernel_19104\3569661354.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                           time   latitude   longitude   depth   mag magType  \
# 0     2024-01-18T02:18:19.690Z  38.807835 -122.823334    2.03  1.49      md
# 1     2024-01-18T02:16:52.710Z  38.808498 -122.823669    2.01  1.33      md
# 2     2024-01-18T01:55:45.006Z  64.994500 -147.409700    5.20  1.50      ml
# 3     2024-01-18T01:48:21.130Z  36.020333 -117.781167    1.55  1.39      ml
# 4     2024-01-18T01:46:32.440Z  38.826668 -122.853836    2.44  0.28      md
# ...                        ...        ...         ...     ...   ...     ...
# 8881  2023-12-19T02:43:10.876Z  -7.242500  119.138700  593.76  4.90      mb
# 8882  2023-12-19T02:42:29.472Z -22.785000  172.366200   10.00  5.30     mww
# 8883  2023-12-19T02:39:21.180Z  33.111333 -115.624833    9.51  1.34      ml
# 8884  2023-12-19T02:35:17.230Z  38.826332 -122.804833    3.06  0.64      md
# 8885  2023-12-19T02:34:46.768Z  57.893500 -153.765300   56.30  1.50      ml
#
#        nst    gap      dmin   rms  ...                   updated  \
# 0     21.0   54.0  0.004681  0.02  ...  2024-01-18T02:19:54.732Z
# 1     23.0   53.0  0.004320  0.02  ...  2024-01-18T02:28:11.196Z
# 2      NaN    NaN       NaN  0.60  ...  2024-01-18T02:03:52.136Z
# 3     27.0   62.0  0.013780  0.16  ...  2024-01-18T01:54:25.834Z
# 4     10.0   99.0  0.002529  0.01  ...  2024-01-18T02:04:12.038Z
# ...    ...    ...       ...   ...  ...                       ...
# 8881  95.0   26.0  2.074000  0.75  ...  2024-01-16T01:30:21.040Z
# 8882  64.0   74.0  4.546000  0.74  ...  2024-01-15T23:45:16.040Z
# 8883  32.0   93.0  0.066410  0.19  ...  2023-12-19T15:49:01.616Z
# 8884   8.0  147.0  0.005036  0.01  ...  2023-12-19T04:50:10.666Z
# 8885   NaN    NaN       NaN  0.32  ...  2024-01-05T18:45:34.407Z
#
#                                  place        type horizontalError depthError  \
# 0          7 km WNW of The Geysers, CA  earthquake            0.22      0.310
# 1          7 km WNW of The Geysers, CA  earthquake            0.19      0.340
# 2             10 km ENE of Fox, Alaska  earthquake             NaN      0.300
# 3          15 km NE of Little Lake, CA  earthquake            0.17      0.160
# 4         10 km WNW of The Geysers, CA  earthquake            0.40      1.070
# ...                                ...         ...             ...        ...
# 8881     142 km NNE of Bima, Indonesia  earthquake            3.86      6.268
# 8882  southeast of the Loyalty Islands  earthquake           10.15      1.808
# 8883         8 km N of Westmorland, CA  earthquake            0.21      0.520
# 8884        7 km NW of The Geysers, CA  earthquake            1.08      1.470
# 8885   41 km NNE of Larsen Bay, Alaska  earthquake             NaN      0.500
#
#       magError  magNst     status  locationSource magSource
# 0        0.150    22.0  automatic              nc        nc
# 1        0.140    23.0  automatic              nc        nc
# 2          NaN     NaN  automatic              ak        ak
# 3        0.139    11.0  automatic              ci        ci
# 4        0.160    11.0  automatic              nc        nc
# ...        ...     ...        ...             ...       ...
# 8881     0.054   107.0   reviewed              us        us
# 8882     0.075    17.0   reviewed              us        us
# 8883     0.214    20.0   reviewed              ci        ci
# 8884     0.120     7.0  automatic              nc        nc
# 8885       NaN     NaN   reviewed              ak        ak
#
# [8886 rows x 22 columns]

# %%
earthquake_data.head(10)
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2024-01-18T02:18:19.690Z  38.807835 -122.823334   2.03  1.49      md  21.0
# 1  2024-01-18T02:16:52.710Z  38.808498 -122.823669   2.01  1.33      md  23.0
# 2  2024-01-18T01:55:45.006Z  64.994500 -147.409700   5.20  1.50      ml   NaN
# 3  2024-01-18T01:48:21.130Z  36.020333 -117.781167   1.55  1.39      ml  27.0
# 4  2024-01-18T01:46:32.440Z  38.826668 -122.853836   2.44  0.28      md  10.0
# 5  2024-01-18T01:38:29.351Z  -6.303000  101.441700  10.00  4.60      mb  26.0
# 6  2024-01-18T01:16:04.860Z  33.187167 -116.388667  11.55  0.77      ml  29.0
# 7  2024-01-18T01:09:34.030Z  33.180667 -116.393000  11.40  1.53      ml  71.0
# 8  2024-01-18T01:02:29.940Z  33.179833 -116.391833  11.48  1.48      ml  65.0
# 9  2024-01-18T01:02:09.990Z  33.180333 -116.391500  11.38  1.50      ml  69.0
#
#      gap      dmin   rms  ...                   updated  \
# 0   54.0  0.004681  0.02  ...  2024-01-18T02:19:54.732Z
# 1   53.0  0.004320  0.02  ...  2024-01-18T02:28:11.196Z
# 2    NaN       NaN  0.60  ...  2024-01-18T02:03:52.136Z
# 3   62.0  0.013780  0.16  ...  2024-01-18T01:54:25.834Z
# 4   99.0  0.002529  0.01  ...  2024-01-18T02:04:12.038Z
# 5  190.0  2.449000  0.80  ...  2024-01-18T01:55:33.040Z
# 6   50.0  0.084270  0.19  ...  2024-01-18T01:22:06.979Z
# 7   18.0  0.089620  0.20  ...  2024-01-18T01:46:24.805Z
# 8   18.0  0.090650  0.20  ...  2024-01-18T01:13:34.470Z
# 9   18.0  0.090230  0.20  ...  2024-01-18T01:12:30.790Z
#
#                                place        type horizontalError depthError  \
# 0        7 km WNW of The Geysers, CA  earthquake            0.22      0.310
# 1        7 km WNW of The Geysers, CA  earthquake            0.19      0.340
# 2           10 km ENE of Fox, Alaska  earthquake             NaN      0.300
# 3        15 km NE of Little Lake, CA  earthquake            0.17      0.160
# 4       10 km WNW of The Geysers, CA  earthquake            0.40      1.070
# 5  291 km SSW of Bengkulu, Indonesia  earthquake           10.38      1.948
# 6      8 km S of Borrego Springs, CA  earthquake            0.29      0.540
# 7    8 km SSW of Borrego Springs, CA  earthquake            0.15      0.300
# 8      9 km S of Borrego Springs, CA  earthquake            0.17      0.330
# 9      8 km S of Borrego Springs, CA  earthquake            0.15      0.300
#
#    magError  magNst     status  locationSource magSource
# 0     0.150    22.0  automatic              nc        nc
# 1     0.140    23.0  automatic              nc        nc
# 2       NaN     NaN  automatic              ak        ak
# 3     0.139    11.0  automatic              ci        ci
# 4     0.160    11.0  automatic              nc        nc
# 5     0.136    16.0   reviewed              us        us
# 6     0.323    10.0  automatic              ci        ci
# 7     0.193    25.0   reviewed              ci        ci
# 8     0.173    18.0  automatic              ci        ci
# 9     0.160    26.0  automatic              ci        ci
#
# [10 rows x 22 columns]

# %%
## tail

earthquake_data.tail()
# Out:
#                           time   latitude   longitude   depth   mag magType  \
# 8881  2023-12-19T02:43:10.876Z  -7.242500  119.138700  593.76  4.90      mb
# 8882  2023-12-19T02:42:29.472Z -22.785000  172.366200   10.00  5.30     mww
# 8883  2023-12-19T02:39:21.180Z  33.111333 -115.624833    9.51  1.34      ml
# 8884  2023-12-19T02:35:17.230Z  38.826332 -122.804833    3.06  0.64      md
# 8885  2023-12-19T02:34:46.768Z  57.893500 -153.765300   56.30  1.50      ml
#
#        nst    gap      dmin   rms  ...                   updated  \
# 8881  95.0   26.0  2.074000  0.75  ...  2024-01-16T01:30:21.040Z
# 8882  64.0   74.0  4.546000  0.74  ...  2024-01-15T23:45:16.040Z
# 8883  32.0   93.0  0.066410  0.19  ...  2023-12-19T15:49:01.616Z
# 8884   8.0  147.0  0.005036  0.01  ...  2023-12-19T04:50:10.666Z
# 8885   NaN    NaN       NaN  0.32  ...  2024-01-05T18:45:34.407Z
#
#                                  place        type horizontalError depthError  \
# 8881     142 km NNE of Bima, Indonesia  earthquake            3.86      6.268
# 8882  southeast of the Loyalty Islands  earthquake           10.15      1.808
# 8883         8 km N of Westmorland, CA  earthquake            0.21      0.520
# 8884        7 km NW of The Geysers, CA  earthquake            1.08      1.470
# 8885   41 km NNE of Larsen Bay, Alaska  earthquake             NaN      0.500
#
#       magError  magNst     status  locationSource magSource
# 8881     0.054   107.0   reviewed              us        us
# 8882     0.075    17.0   reviewed              us        us
# 8883     0.214    20.0   reviewed              ci        ci
# 8884     0.120     7.0  automatic              nc        nc
# 8885       NaN     NaN   reviewed              ak        ak
#
# [5 rows x 22 columns]

# %%
# info about dataset
earthquake_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8886 entries, 0 to 8885
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             8886 non-null   object
#  1   latitude         8886 non-null   float64
#  2   longitude        8886 non-null   float64
#  3   depth            8886 non-null   float64
#  4   mag              8886 non-null   float64
#  5   magType          8886 non-null   object
#  6   nst              7092 non-null   float64
#  7   gap              7092 non-null   float64
#  8   dmin             5965 non-null   float64
#  9   rms              8886 non-null   float64
#  10  net              8886 non-null   object
#  11  id               8886 non-null   object
#  12  updated          8886 non-null   object
#  13  place            8886 non-null   object
#  14  type             8886 non-null   object
#  15  horizontalError  6349 non-null   float64
#  16  depthError       8886 non-null   float64
#  17  magError         7076 non-null   float64
#  18  magNst           7090 non-null   float64
#  19  status           8886 non-null   object
#  20  locationSource   8886 non-null   object
#  21  magSource        8886 non-null   object
# dtypes: float64(12), object(10)
# memory usage: 1.5+ MB

# %%
##  to check for missing values
## but zero is not a missing value for python
## when no value -python will put NAN
earthquake_data.isnull().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   0
# magType               0
# nst                1794
# gap                1794
# dmin               2921
# rms                   0
# net                   0
# id                    0
# updated               0
# place                 0
# type                  0
# horizontalError    2537
# depthError            0
# magError           1810
# magNst             1796
# status                0
# locationSource        0
# magSource             0
# dtype: int64

# %%
##basic statistics

earthquake_data.describe()
# Out:
#           latitude    longitude        depth          mag          nst  \
# count  8886.000000  8886.000000  8886.000000  8886.000000  7092.000000
# mean     39.308700  -111.205884    22.779244     1.636482    24.467851
# std      18.276848    68.838488    51.627071     1.223509    23.427687
# min     -65.494800  -179.957700    -3.160000    -1.270000     2.000000
# 25%      33.408500  -150.502125     3.000000     0.830000    10.000000
# 50%      38.816250  -122.264500     7.738300     1.420000    18.000000
# 75%      53.236350  -114.302992    16.490000     2.050000    32.000000
# max      80.512900   179.884600   660.826000     7.500000   598.000000
#
#                gap         dmin          rms  horizontalError   depthError  \
# count  7092.000000  5965.000000  8886.000000      6349.000000  8886.000000
# mean    109.605255     0.553678     0.276822         1.638979     2.037707
# std      63.652406     2.196805     0.273490         2.914440     6.507358
# min      12.000000     0.000000     0.000000         0.000000     0.000000
# 25%      64.000000     0.012000     0.090000         0.250000     0.440000
# 50%      91.000000     0.053830     0.170000         0.450000     0.750000
# 75%     140.000000     0.139100     0.420000         1.000000     1.500000
# max     344.000000    43.556000     3.250000        17.780000   449.100000
#
#           magError       magNst
# count  7076.000000  7090.000000
# mean      0.247804    16.977292
# std       0.390754    29.095417
# min       0.000000     0.000000
# 25%       0.110000     6.000000
# 50%       0.173000    11.000000
# 75%       0.244314    19.000000
# max       5.180000   722.000000

# %%
## grouping by

earthquake_data.groupby(['mag']).sum(numeric_only=True)
# Out:
#         latitude   longitude    depth    nst    gap   dmin   rms  \
# mag
# -1.27  58.241167 -155.236333    1.810    5.0  180.0  0.000  0.19
# -1.18  60.026000 -153.062333    0.990    5.0  114.0  0.000  0.15
# -1.13  60.003833 -153.067333    0.590    5.0  119.0  0.000  0.07
# -1.05  59.993500 -153.067167    1.570    5.0  137.0  0.000  0.09
# -1.03  60.042333 -153.059667    0.860    6.0   85.0  0.000  0.07
# ...          ...         ...      ...    ...    ...    ...   ...
#  6.30  -2.953600  139.351800   33.000  122.0   21.0  1.418  1.14
#  6.40  36.506100   70.599400  206.561  107.0   32.0  3.114  1.15
#  6.50  44.579600  148.990300   23.844  119.0   49.0  4.611  1.07
#  6.70   4.860600  126.186100   68.017  129.0   27.0  2.276  1.08
#  7.50  37.497600  137.241600   10.000  120.0   39.0  0.970  1.01
#
#        horizontalError  depthError  magError  magNst
# mag
# -1.27             0.97       1.710  0.211392     5.0
# -1.18             0.34       1.260  0.318225     4.0
# -1.13             0.24       1.120  0.296279     5.0
# -1.05             0.41       0.310  0.242754     5.0
# -1.03             0.26       0.310  0.390924     6.0
# ...                ...         ...       ...     ...
#  6.30             6.50       1.774  0.073000    18.0
#  6.40             5.97       4.786  0.049000    40.0
#  6.50             7.98       4.633  0.078000    16.0
#  6.70             7.46       3.911  0.060000    27.0
#  7.50             5.43       1.831  0.047000    43.0
#
# [560 rows x 11 columns]

# %%
# Count the number of occurrences for each magType
magType_counts = earthquake_data['magType'].value_counts()
magType_counts = magType_counts.reset_index()
magType_counts
# Out:
#   magType  count
# 0      ml   5586
# 1      md   2475
# 2      mb    700
# 3     mww     71
# 4     mwr     30
# 5   mb_lg     13
# 6      mh      5
# 7      mw      4
# 8     mlv      1
# 9     mwp      1

# %%
## Pie chart

fig, ax = plt.subplots(figsize=(10, 10))
magType_counts.plot(kind = 'pie', y='count', labels = magType_counts['magType'], autopct =' %1.2f', ax=ax)
plt.title('Earthquake magType Distribution')

plt.show()

# %%
import calendar

# %%
# Extract the year and month from the time field
earthquake_data['Year'] = earthquake_data['time'].apply(lambda x: int(x[:4]))
earthquake_data['Month'] = earthquake_data['time'].apply(lambda x: calendar.month_name[int(x[5:7])])

earthquake_data
# Out:
#                           time   latitude   longitude   depth   mag magType  \
# 0     2024-01-18T02:18:19.690Z  38.807835 -122.823334    2.03  1.49      md
# 1     2024-01-18T02:16:52.710Z  38.808498 -122.823669    2.01  1.33      md
# 2     2024-01-18T01:55:45.006Z  64.994500 -147.409700    5.20  1.50      ml
# 3     2024-01-18T01:48:21.130Z  36.020333 -117.781167    1.55  1.39      ml
# 4     2024-01-18T01:46:32.440Z  38.826668 -122.853836    2.44  0.28      md
# ...                        ...        ...         ...     ...   ...     ...
# 8881  2023-12-19T02:43:10.876Z  -7.242500  119.138700  593.76  4.90      mb
# 8882  2023-12-19T02:42:29.472Z -22.785000  172.366200   10.00  5.30     mww
# 8883  2023-12-19T02:39:21.180Z  33.111333 -115.624833    9.51  1.34      ml
# 8884  2023-12-19T02:35:17.230Z  38.826332 -122.804833    3.06  0.64      md
# 8885  2023-12-19T02:34:46.768Z  57.893500 -153.765300   56.30  1.50      ml
#
#        nst    gap      dmin   rms  ...        type horizontalError depthError  \
# 0     21.0   54.0  0.004681  0.02  ...  earthquake            0.22      0.310
# 1     23.0   53.0  0.004320  0.02  ...  earthquake            0.19      0.340
# 2      NaN    NaN       NaN  0.60  ...  earthquake             NaN      0.300
# 3     27.0   62.0  0.013780  0.16  ...  earthquake            0.17      0.160
# 4     10.0   99.0  0.002529  0.01  ...  earthquake            0.40      1.070
# ...    ...    ...       ...   ...  ...         ...             ...        ...
# 8881  95.0   26.0  2.074000  0.75  ...  earthquake            3.86      6.268
# 8882  64.0   74.0  4.546000  0.74  ...  earthquake           10.15      1.808
# 8883  32.0   93.0  0.066410  0.19  ...  earthquake            0.21      0.520
# 8884   8.0  147.0  0.005036  0.01  ...  earthquake            1.08      1.470
# 8885   NaN    NaN       NaN  0.32  ...  earthquake             NaN      0.500
#
#      magError magNst     status  locationSource  magSource  Year     Month
# 0       0.150   22.0  automatic              nc         nc  2024   January
# 1       0.140   23.0  automatic              nc         nc  2024   January
# 2         NaN    NaN  automatic              ak         ak  2024   January
# 3       0.139   11.0  automatic              ci         ci  2024   January
# 4       0.160   11.0  automatic              nc         nc  2024   January
# ...       ...    ...        ...             ...        ...   ...       ...
# 8881    0.054  107.0   reviewed              us         us  2023  December
# 8882    0.075   17.0   reviewed              us         us  2023  December
# 8883    0.214   20.0   reviewed              ci         ci  2023  December
# 8884    0.120    7.0  automatic              nc         nc  2023  December
# 8885      NaN    NaN   reviewed              ak         ak  2023  December
#
# [8886 rows x 24 columns]

# %%
# Group the data by month and calculate the median magnitude
monthly_magnitudes = earthquake_data.groupby('Month')['mag'].median()
monthly_magnitudes
# Out:
# Month
# December    1.5
# January     1.4
# Name: mag, dtype: float64

# %%
# Create a histogram with the month names on the x-axis
plt.figure(figsize=(8, 4))
plt.bar(monthly_magnitudes.index, monthly_magnitudes.values)
plt.title('Histogram of Earthquake Magnitudes by Month')
plt.xlabel('Month')
plt.ylabel('Median Magnitude')
plt.show()

# %%
# Select the first 30 days of data
head_30days = earthquake_data.head(30)

# %%
# Create a histogram of 'MAG' (magnitude) for the first 30 days
plt.figure(figsize=(10, 6))
plt.hist(head_30days['mag'], bins=10, alpha=0.5, label='First 30 Days')
plt.title('Histogram of Earthquake Magnitudes for the First 30 Days')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
