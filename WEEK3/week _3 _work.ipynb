# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
# Out:
# C:\Users\kater\AppData\Local\Temp\ipykernel_7824\615924438.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Read the earthquake data
earthquake_data = pd.read_csv('all_month.csv')
earthquake_data
# Out:
#                           time   latitude   longitude   depth   mag magType  \
# 0     2024-01-18T02:18:19.690Z  38.807835 -122.823334    2.03  1.49      md
# 1     2024-01-18T02:16:52.710Z  38.808498 -122.823669    2.01  1.33      md
# 2     2024-01-18T01:55:45.006Z  64.994500 -147.409700    5.20  1.50      ml
# 3     2024-01-18T01:48:21.130Z  36.020333 -117.781167    1.55  1.39      ml
# 4     2024-01-18T01:46:32.440Z  38.826668 -122.853836    2.44  0.28      md
# ...                        ...        ...         ...     ...   ...     ...
# 8881  2023-12-19T02:43:10.876Z  -7.242500  119.138700  593.76  4.90      mb
# 8882  2023-12-19T02:42:29.472Z -22.785000  172.366200   10.00  5.30     mww
# 8883  2023-12-19T02:39:21.180Z  33.111333 -115.624833    9.51  1.34      ml
# 8884  2023-12-19T02:35:17.230Z  38.826332 -122.804833    3.06  0.64      md
# 8885  2023-12-19T02:34:46.768Z  57.893500 -153.765300   56.30  1.50      ml
#
#        nst    gap      dmin   rms  ...                   updated  \
# 0     21.0   54.0  0.004681  0.02  ...  2024-01-18T02:19:54.732Z
# 1     23.0   53.0  0.004320  0.02  ...  2024-01-18T02:28:11.196Z
# 2      NaN    NaN       NaN  0.60  ...  2024-01-18T02:03:52.136Z
# 3     27.0   62.0  0.013780  0.16  ...  2024-01-18T01:54:25.834Z
# 4     10.0   99.0  0.002529  0.01  ...  2024-01-18T02:04:12.038Z
# ...    ...    ...       ...   ...  ...                       ...
# 8881  95.0   26.0  2.074000  0.75  ...  2024-01-16T01:30:21.040Z
# 8882  64.0   74.0  4.546000  0.74  ...  2024-01-15T23:45:16.040Z
# 8883  32.0   93.0  0.066410  0.19  ...  2023-12-19T15:49:01.616Z
# 8884   8.0  147.0  0.005036  0.01  ...  2023-12-19T04:50:10.666Z
# 8885   NaN    NaN       NaN  0.32  ...  2024-01-05T18:45:34.407Z
#
#                                  place        type horizontalError depthError  \
# 0          7 km WNW of The Geysers, CA  earthquake            0.22      0.310
# 1          7 km WNW of The Geysers, CA  earthquake            0.19      0.340
# 2             10 km ENE of Fox, Alaska  earthquake             NaN      0.300
# 3          15 km NE of Little Lake, CA  earthquake            0.17      0.160
# 4         10 km WNW of The Geysers, CA  earthquake            0.40      1.070
# ...                                ...         ...             ...        ...
# 8881     142 km NNE of Bima, Indonesia  earthquake            3.86      6.268
# 8882  southeast of the Loyalty Islands  earthquake           10.15      1.808
# 8883         8 km N of Westmorland, CA  earthquake            0.21      0.520
# 8884        7 km NW of The Geysers, CA  earthquake            1.08      1.470
# 8885   41 km NNE of Larsen Bay, Alaska  earthquake             NaN      0.500
#
#       magError  magNst     status  locationSource magSource
# 0        0.150    22.0  automatic              nc        nc
# 1        0.140    23.0  automatic              nc        nc
# 2          NaN     NaN  automatic              ak        ak
# 3        0.139    11.0  automatic              ci        ci
# 4        0.160    11.0  automatic              nc        nc
# ...        ...     ...        ...             ...       ...
# 8881     0.054   107.0   reviewed              us        us
# 8882     0.075    17.0   reviewed              us        us
# 8883     0.214    20.0   reviewed              ci        ci
# 8884     0.120     7.0  automatic              nc        nc
# 8885       NaN     NaN   reviewed              ak        ak
#
# [8886 rows x 22 columns]

# %%
latest_events = earthquake_data.head()
latest_events
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2024-01-18T02:18:19.690Z  38.807835 -122.823334   2.03  1.49      md  21.0
# 1  2024-01-18T02:16:52.710Z  38.808498 -122.823669   2.01  1.33      md  23.0
# 2  2024-01-18T01:55:45.006Z  64.994500 -147.409700   5.20  1.50      ml   NaN
# 3  2024-01-18T01:48:21.130Z  36.020333 -117.781167   1.55  1.39      ml  27.0
# 4  2024-01-18T01:46:32.440Z  38.826668 -122.853836   2.44  0.28      md  10.0
#
#     gap      dmin   rms  ...                   updated  \
# 0  54.0  0.004681  0.02  ...  2024-01-18T02:19:54.732Z
# 1  53.0  0.004320  0.02  ...  2024-01-18T02:28:11.196Z
# 2   NaN       NaN  0.60  ...  2024-01-18T02:03:52.136Z
# 3  62.0  0.013780  0.16  ...  2024-01-18T01:54:25.834Z
# 4  99.0  0.002529  0.01  ...  2024-01-18T02:04:12.038Z
#
#                           place        type horizontalError depthError  \
# 0   7 km WNW of The Geysers, CA  earthquake            0.22       0.31
# 1   7 km WNW of The Geysers, CA  earthquake            0.19       0.34
# 2      10 km ENE of Fox, Alaska  earthquake             NaN       0.30
# 3   15 km NE of Little Lake, CA  earthquake            0.17       0.16
# 4  10 km WNW of The Geysers, CA  earthquake            0.40       1.07
#
#    magError  magNst     status  locationSource magSource
# 0     0.150    22.0  automatic              nc        nc
# 1     0.140    23.0  automatic              nc        nc
# 2       NaN     NaN  automatic              ak        ak
# 3     0.139    11.0  automatic              ci        ci
# 4     0.160    11.0  automatic              nc        nc
#
# [5 rows x 22 columns]

# %%
# Calculate the total magnitude for the first 20 rows
total_magnitude = latest_events['mag'].sum()
total_magnitude
# Out:
# 5.99

# %%
# Count the number of occurrences for each magType
magType_counts = earthquake_data['magType'].value_counts()
magType_counts = magType_counts.reset_index()
magType_counts
# Out:
#   magType  count
# 0      ml   5586
# 1      md   2475
# 2      mb    700
# 3     mww     71
# 4     mwr     30
# 5   mb_lg     13
# 6      mh      5
# 7      mw      4
# 8     mlv      1
# 9     mwp      1

# %%
## Pie chart

fig, ax = plt.subplots(figsize=(10, 10))
magType_counts.plot(kind = 'pie', y='count', labels = magType_counts['magType'], autopct =' %1.2f', ax=ax)
plt.title('Pie Chart of Earthquake magType Distribution')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

# Your existing code
fig, ax = plt.subplots(figsize=(10, 10)) 
magType_counts.plot(kind='pie', y='count', labels=magType_counts['magType'], autopct='%1.2f', ax=ax) 
plt.title('Earthquake magType Distribution')

# Create custom legend labels including percentage
legend_labels = [f"{mag_type}: {count} ({percentage}%)"
                 for mag_type, count, percentage in zip(magType_counts['magType'], magType_counts['count'], magType_counts['percentage'])]

# Add custom legend with updated labels
plt.legend(legend_labels, loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'percentage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 10
#       6 plt.title('Earthquake magType Distribution')
#       8 # Create custom legend labels including percentage
#       9 legend_labels = [f"{mag_type}: {count} ({percentage}%)"
# ---> 10                  for mag_type, count, percentage in zip(magType_counts['magType'], magType_counts['count'], magType_counts['percentage'])]
#      12 # Add custom legend with updated labels
#      13 plt.legend(legend_labels, loc='upper right')
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'percentage'

# %%
def make_label(val, total):
    label = f"{magType_counts['magType'][val]:.2f}%" 
    return f"{magType_counts['magType'][val]} ({label})"

fig, ax = plt.subplots(figsize=(10, 10))  
magType_counts.plot(kind='pie', y='count', 
                    labels=[make_label(val, sum(magType_counts)) for val in magType_counts.index],
                    autopct='%1.2f%%', ax=ax)
plt.title('Earthquake magType Distribution') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       3     return f"{magType_counts['magType'][val]} ({label})"
#       5 fig, ax = plt.subplots(figsize=(10, 10))
#       6 magType_counts.plot(kind='pie', y='count',
# ----> 7                     labels=[make_label(val, sum(magType_counts)) for val in magType_counts.index],
#       8                     autopct='%1.2f%%', ax=ax)
#       9 plt.title('Earthquake magType Distribution')
#      10 plt.show()
#
# Cell In[21], line 7, in <listcomp>(.0)
#       3     return f"{magType_counts['magType'][val]} ({label})"
#       5 fig, ax = plt.subplots(figsize=(10, 10))
#       6 magType_counts.plot(kind='pie', y='count',
# ----> 7                     labels=[make_label(val, sum(magType_counts)) for val in magType_counts.index],
#       8                     autopct='%1.2f%%', ax=ax)
#       9 plt.title('Earthquake magType Distribution')
#      10 plt.show()
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
## Bar chart

months=earthquake_data['Month']
Magnitude = earthquake_data['mag']
plt.bar(months, Magnitude, width = 0.5, color = 'blue')
plt.xlabel('time')
plt.ylabel('mag')
plt.title('The distribution of earthquake magnitudes')
plt.show()

# %%
import calendar

# %%
# Extract the year and month from the time field
earthquake_data['Year'] = earthquake_data['time'].apply(lambda x: int(x[:4]))
earthquake_data['Month'] = earthquake_data['time'].apply(lambda x: calendar.month_name[int(x[5:7])])
earthquake_data['Day'] = earthquake_data['time'].apply(lambda x: calendar.day_name[int(x[7:9])])

earthquake_data
# Out:
#                           time   latitude   longitude   depth   mag magType  \
# 0     2024-01-18T02:18:19.690Z  38.807835 -122.823334    2.03  1.49      md
# 1     2024-01-18T02:16:52.710Z  38.808498 -122.823669    2.01  1.33      md
# 2     2024-01-18T01:55:45.006Z  64.994500 -147.409700    5.20  1.50      ml
# 3     2024-01-18T01:48:21.130Z  36.020333 -117.781167    1.55  1.39      ml
# 4     2024-01-18T01:46:32.440Z  38.826668 -122.853836    2.44  0.28      md
# ...                        ...        ...         ...     ...   ...     ...
# 8881  2023-12-19T02:43:10.876Z  -7.242500  119.138700  593.76  4.90      mb
# 8882  2023-12-19T02:42:29.472Z -22.785000  172.366200   10.00  5.30     mww
# 8883  2023-12-19T02:39:21.180Z  33.111333 -115.624833    9.51  1.34      ml
# 8884  2023-12-19T02:35:17.230Z  38.826332 -122.804833    3.06  0.64      md
# 8885  2023-12-19T02:34:46.768Z  57.893500 -153.765300   56.30  1.50      ml
#
#        nst    gap      dmin   rms  ... horizontalError depthError magError  \
# 0     21.0   54.0  0.004681  0.02  ...            0.22      0.310    0.150
# 1     23.0   53.0  0.004320  0.02  ...            0.19      0.340    0.140
# 2      NaN    NaN       NaN  0.60  ...             NaN      0.300      NaN
# 3     27.0   62.0  0.013780  0.16  ...            0.17      0.160    0.139
# 4     10.0   99.0  0.002529  0.01  ...            0.40      1.070    0.160
# ...    ...    ...       ...   ...  ...             ...        ...      ...
# 8881  95.0   26.0  2.074000  0.75  ...            3.86      6.268    0.054
# 8882  64.0   74.0  4.546000  0.74  ...           10.15      1.808    0.075
# 8883  32.0   93.0  0.066410  0.19  ...            0.21      0.520    0.214
# 8884   8.0  147.0  0.005036  0.01  ...            1.08      1.470    0.120
# 8885   NaN    NaN       NaN  0.32  ...             NaN      0.500      NaN
#
#      magNst     status  locationSource  magSource  Year     Month     Day
# 0      22.0  automatic              nc         nc  2024   January  Sunday
# 1      23.0  automatic              nc         nc  2024   January  Sunday
# 2       NaN  automatic              ak         ak  2024   January  Sunday
# 3      11.0  automatic              ci         ci  2024   January  Sunday
# 4      11.0  automatic              nc         nc  2024   January  Sunday
# ...     ...        ...             ...        ...   ...       ...     ...
# 8881  107.0   reviewed              us         us  2023  December  Sunday
# 8882   17.0   reviewed              us         us  2023  December  Sunday
# 8883   20.0   reviewed              ci         ci  2023  December  Sunday
# 8884    7.0  automatic              nc         nc  2023  December  Sunday
# 8885    NaN   reviewed              ak         ak  2023  December  Sunday
#
# [8886 rows x 25 columns]

# %%
# Group the data by month and calculate the mean magnitude
monthly_magnitudes = earthquake_data.groupby('Month')['mag'].median()
monthly_magnitudes
# Out:
# Month
# December    1.5
# January     1.4
# Name: mag, dtype: float64

# %%
# Create a histogram with the month names on the x-axis
plt.figure(figsize=(8, 4))
plt.bar(monthly_magnitudes.index, monthly_magnitudes.values)
plt.title('Histogram of Earthquake Magnitudes by Month')
plt.xlabel('Month')
plt.ylabel('Median Magnitude')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %%
# Compute the monthly median magnitudes
median_magnitudes = earthquake_data.groupby(['Year', 'Month'])['mag'].median()
median_magnitudes
# Out:
# Year  Month
# 2023  12       1.5
# 2024  1        1.4
# Name: mag, dtype: float64

# %%
# Select the first 30 days of data
head_30days = earthquake_data.head(30)

# %%
# Create a histogram of 'MAG' (magnitude) for the first 30 days
plt.figure(figsize=(10, 6))
plt.hist(head_30days['mag'], bins=10, alpha=0.5, label='First 30 Days')
plt.title('Histogram of Earthquake Magnitudes for the First 30 Days')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
## Bar chart

plt.bar(earthquake_data['Month'], earthquake_data['mag'])
plt.xlabel('time')
plt.ylabel('mag')
plt.title('The distribution of earthquake magnitudes')
plt.show()

# %%
earthquake_datadata = pd.read_csv('all_month.csv')
earthquake_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 earthquake_datadata = pd.read_csv('all_month.csv')
# ----> 2 earthquake_data
#
# NameError: name 'earthquake_data' is not defined

# %%
print(data.head())
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2024-01-18T02:18:19.690Z  38.807835 -122.823334   2.03  1.49      md  21.0
# 1  2024-01-18T02:16:52.710Z  38.808498 -122.823669   2.01  1.33      md  23.0
# 2  2024-01-18T01:55:45.006Z  64.994500 -147.409700   5.20  1.50      ml   NaN
# 3  2024-01-18T01:48:21.130Z  36.020333 -117.781167   1.55  1.39      ml  27.0
# 4  2024-01-18T01:46:32.440Z  38.826668 -122.853836   2.44  0.28      md  10.0
#
#     gap      dmin   rms  ...                   updated  \
# 0  54.0  0.004681  0.02  ...  2024-01-18T02:19:54.732Z
# 1  53.0  0.004320  0.02  ...  2024-01-18T02:28:11.196Z
# 2   NaN       NaN  0.60  ...  2024-01-18T02:03:52.136Z
# 3  62.0  0.013780  0.16  ...  2024-01-18T01:54:25.834Z
# 4  99.0  0.002529  0.01  ...  2024-01-18T02:04:12.038Z
#
#                           place        type horizontalError depthError  \
# 0   7 km WNW of The Geysers, CA  earthquake            0.22       0.31
# 1   7 km WNW of The Geysers, CA  earthquake            0.19       0.34
# 2      10 km ENE of Fox, Alaska  earthquake             NaN       0.30
# 3   15 km NE of Little Lake, CA  earthquake            0.17       0.16
# 4  10 km WNW of The Geysers, CA  earthquake            0.40       1.07
#
#    magError  magNst     status  locationSource magSource
# 0     0.150    22.0  automatic              nc        nc
# 1     0.140    23.0  automatic              nc        nc
# 2       NaN     NaN  automatic              ak        ak
# 3     0.139    11.0  automatic              ci        ci
# 4     0.160    11.0  automatic              nc        nc
#
# [5 rows x 22 columns]

# %%
## Bar chart

plt.bar(data['time'], data['mag'])
plt.xlabel('time')
plt.ylabel('mag')
plt.title('The distribution of earthquake magnitudes')
plt.show()

# %%
date_s = ['time']
mag_s = ['mag']
plt.plot(data['time'], data['mag'], color = 'b', marker = 'o', label = 'magnitude')
plt.xlabel('Time')
plt.ylabel('Magnitude')
plt.title('The frequency of earthquakes over time')

plt.legend()
plt.show()

# %%
## Time series Line chart

data['time'] = pd.to_datetime(data['time'])
plt.plot(data['time'], data['mag'])
plt.xlabel('Time')
plt.ylabel('Magnitude')
plt.title('The frequency of earthquakes over time')

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with a datetime column named 'timestamp' and numerical data column 'value'
# Make sure to replace 'timestamp' and 'value' with your actual column names

# Convert the 'timestamp' column to datetime if not already in datetime format
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Set the 'timestamp' column as the DataFrame index
df.set_index('timestamp', inplace=True)

# Resample the data over weekly intervals and aggregate with mean (you can use other aggregation functions)
df_weekly = df.resample('W').mean()

# Plot the aggregated data using Matplotlib
plt.figure(figsize=(10, 6))
plt.plot(df_weekly.index, df_weekly['value'], marker='o', linestyle='-')
plt.title('Weekly Aggregated Time Series')
plt.xlabel('Date')
plt.ylabel('Aggregated Value')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'Data' is your DataFrame with 'Time' and 'Magnitude' columns
# Make sure to replace 'Time' and 'Magnitude' with your actual column names

# Convert the 'Time' column to datetime if not already in datetime format
data['time'] = pd.to_datetime(data['time'])

# Set the 'Time' column as the DataFrame index
data.set_index('time', inplace=True)

# Resample the data over weekly intervals and aggregate with mean
data_weekly = data.resample('W').mean()

# Plot the aggregated data using Matplotlib
plt.figure(figsize=(10, 6))
plt.plot(data_weekly.index, Data_weekly['magnitude'], marker='o', linestyle='-')
plt.title('Weekly Aggregated Time Series - Magnitude')
plt.xlabel('Time')
plt.ylabel('Aggregated Magnitude')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       2 import matplotlib.pyplot as plt
#       4 # Assuming 'Data' is your DataFrame with 'Time' and 'Magnitude' columns
#       5 # Make sure to replace 'Time' and 'Magnitude' with your actual column names
#       6
#       7 # Convert the 'Time' column to datetime if not already in datetime format
# ----> 8 data['time'] = pd.to_datetime(data['time'])
#      10 # Set the 'Time' column as the DataFrame index
#      11 data.set_index('time', inplace=True)
#
# NameError: name 'data' is not defined

# %%
data['time'] = pd.to_datetime(data['time'])  # Convert the date column to datetime if not already
data_resampled = data.resample('6M', on='time').mean()  # Resample data for every 6 months
# Out:
# C:\Users\kater\AppData\Local\Temp\ipykernel_5960\2192062773.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_resampled = data.resample('6M', on='time').mean()  # Resample data for every 6 months
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:863, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     861     preserve_dtype = True
# --> 863 result = self._aggregate_series_pure_python(obj, func)
#     865 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:884, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     883 for i, group in enumerate(splitter):
# --> 884     res = func(group)
#     885     res = extract_result(res)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6529, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6521 @doc(make_doc("mean", ndim=1))
#    6522 def mean(
#    6523     self,
#    (...)
#    6527     **kwargs,
#    6528 ):
# -> 6529     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:12413, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12406 def mean(
#   12407     self,
#   12408     axis: Axis | None = 0,
#    (...)
#   12411     **kwargs,
#   12412 ) -> Series | float:
# > 12413     return self._stat_function(
#   12414         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12415     )
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:12370, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12368 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12370 return self._reduce(
#   12371     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12372 )
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6437, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6433     raise TypeError(
#    6434         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6435         "with non-numeric dtypes."
#    6436     )
# -> 6437 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'mlmdmlmwwmbmlmlmlmlmlmlmlmbmbmlmlmbmlmlmlmlmlmlmdmdmlmdmlmlmlmlmlmlmdmlmlmlmdmlmlmdmlmlmlmdmlmlmlmlmb_..._..._..._..._..._lgmbmbmlmdmlmlmdmbmdmlmlmbmwrmdmdmdmdmlmdmlmlmlmlmdmlmbmdmlmlmlmlmlmlmbmdmlmbmbmdmdmlmlmlmlmlmlmdmlmdmdmlmlmlmdmlmlmlmlmlmlmdmlmlmlmlmlmdmlmlmlmlmlmlmlmlmlmlmlmlmlmdmlmlmlmdmlmlmdmlmlmdml' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 data['time'] = pd.to_datetime(data['time'])  # Convert the date column to datetime if not already
# ----> 2 data_resampled = data.resample('6M', on='time').mean()  # Resample data for every 6 months
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:1378, in Resampler.mean(self, numeric_only, *args, **kwargs)
#    1376 maybe_warn_args_and_kwargs(type(self), "mean", args, kwargs)
#    1377 nv.validate_resampler_func("mean", args, kwargs)
# -> 1378 return self._downsample("mean", numeric_only=numeric_only)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:1776, in DatetimeIndexResampler._downsample(self, how, **kwargs)
#    1773 # we are downsampling
#    1774 # we want to call the actual grouper method here
#    1775 if self.axis == 0:
# -> 1776     result = obj.groupby(self._grouper).aggregate(how, **kwargs)
#    1777 else:
#    1778     # test_resample_axis1
#    1779     result = obj.T.groupby(self._grouper).aggregate(how, **kwargs).T
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:187, in Apply.agg(self)
#     184 kwargs = self.kwargs
#     186 if isinstance(func, str):
# --> 187     return self.apply_str()
#     189 if is_dict_like(func):
#     190     return self.agg_dict_like()
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:603, in Apply.apply_str(self)
#     601         else:
#     602             self.kwargs["axis"] = self.axis
# --> 603 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:693, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     691 f = getattr(obj, func)
#     692 if callable(f):
# --> 693     return f(*args, **kwargs)
#     695 # people may aggregate on a non-callable attribute
#     696 # but don't let them think they can pass args to it
#     697 assert len(args) == 0
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1470, in BlockManager.grouped_reduce(self, func)
#    1466 if blk.is_object:
#    1467     # split on object-dtype blocks bc some columns may raise
#    1468     #  while others do not.
#    1469     for sb in blk._split():
# -> 1470         applied = sb.apply(func)
#    1471         result_blocks = extend_blocks(applied, result_blocks)
#    1472 else:
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
import matplotlib.dates as mdates

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# %%
data['time'] = pd.to_datetime(data['time'])  # Convert the date column to datetime if not already
data_resampled = data.resample('6M', on='time').mean()  # Resample data for every 6 months
# Out:
# C:\Users\kater\AppData\Local\Temp\ipykernel_5960\2192062773.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_resampled = data.resample('6M', on='time').mean()  # Resample data for every 6 months
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:863, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     861     preserve_dtype = True
# --> 863 result = self._aggregate_series_pure_python(obj, func)
#     865 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:884, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     883 for i, group in enumerate(splitter):
# --> 884     res = func(group)
#     885     res = extract_result(res)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6529, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6521 @doc(make_doc("mean", ndim=1))
#    6522 def mean(
#    6523     self,
#    (...)
#    6527     **kwargs,
#    6528 ):
# -> 6529     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:12413, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12406 def mean(
#   12407     self,
#   12408     axis: Axis | None = 0,
#    (...)
#   12411     **kwargs,
#   12412 ) -> Series | float:
# > 12413     return self._stat_function(
#   12414         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12415     )
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:12370, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12368 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12370 return self._reduce(
#   12371     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12372 )
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6437, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6433     raise TypeError(
#    6434         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6435         "with non-numeric dtypes."
#    6436     )
# -> 6437 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'mlmdmlmwwmbmlmlmlmlmlmlmlmbmbmlmlmbmlmlmlmlmlmlmdmdmlmdmlmlmlmlmlmlmdmlmlmlmdmlmlmdmlmlmlmdmlmlmlmlmb_..._..._..._..._..._lgmbmbmlmdmlmlmdmbmdmlmlmbmwrmdmdmdmdmlmdmlmlmlmlmdmlmbmdmlmlmlmlmlmlmbmdmlmbmbmdmdmlmlmlmlmlmlmdmlmdmdmlmlmlmdmlmlmlmlmlmlmdmlmlmlmlmlmdmlmlmlmlmlmlmlmlmlmlmlmlmlmdmlmlmlmdmlmlmdmlmlmdml' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 data['time'] = pd.to_datetime(data['time'])  # Convert the date column to datetime if not already
# ----> 2 data_resampled = data.resample('6M', on='time').mean()  # Resample data for every 6 months
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:1378, in Resampler.mean(self, numeric_only, *args, **kwargs)
#    1376 maybe_warn_args_and_kwargs(type(self), "mean", args, kwargs)
#    1377 nv.validate_resampler_func("mean", args, kwargs)
# -> 1378 return self._downsample("mean", numeric_only=numeric_only)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:1776, in DatetimeIndexResampler._downsample(self, how, **kwargs)
#    1773 # we are downsampling
#    1774 # we want to call the actual grouper method here
#    1775 if self.axis == 0:
# -> 1776     result = obj.groupby(self._grouper).aggregate(how, **kwargs)
#    1777 else:
#    1778     # test_resample_axis1
#    1779     result = obj.T.groupby(self._grouper).aggregate(how, **kwargs).T
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:187, in Apply.agg(self)
#     184 kwargs = self.kwargs
#     186 if isinstance(func, str):
# --> 187     return self.apply_str()
#     189 if is_dict_like(func):
#     190     return self.agg_dict_like()
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:603, in Apply.apply_str(self)
#     601         else:
#     602             self.kwargs["axis"] = self.axis
# --> 603 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:693, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     691 f = getattr(obj, func)
#     692 if callable(f):
# --> 693     return f(*args, **kwargs)
#     695 # people may aggregate on a non-callable attribute
#     696 # but don't let them think they can pass args to it
#     697 assert len(args) == 0
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1470, in BlockManager.grouped_reduce(self, func)
#    1466 if blk.is_object:
#    1467     # split on object-dtype blocks bc some columns may raise
#    1468     #  while others do not.
#    1469     for sb in blk._split():
# -> 1470         applied = sb.apply(func)
#    1471         result_blocks = extend_blocks(applied, result_blocks)
#    1472 else:
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# C:\Users\kater\AppData\Local\Temp\ipykernel_19416\1521273946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Create a 2D histogram of the latitude and longitude columns
plt.hist2d(earthquake_data['latitude'], earthquake_data['longitude'], bins=50, cmap='YlGnBu')
# Add a colorbar to the plot
plt.colorbar()

# Set the title and axis labels
plt.title('Earthquake Heatmap')
plt.xlabel('Latitude')
plt.ylabel('Longitude')

# Display the plot
plt.show()

# %%
# Filter the DataFrame to only include rows with a date in January
january_data = head_30days[head_30days['day'].apply(lambda x: x.startswith('2024-01'))]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Select the first 30 days of data
head_30days = earthquake_data.head(30)
head_30days



# Create a histogram of the magnitude column
plt.figure(figsize=(8, 4))
plt.hist(head_30days['mag'], bins=8, alpha=0.9, label='January')
plt.title('Histogram of Earthquake Magnitudes by Day in January')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.legend()

# Set the locations of the x-axis ticks
plt.xticks(np.arange(1, 8, 0.5))

# Display the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
earthquake_data

# Create a 2D histogram of the latitude and longitude columns
plt.hist2d(earthquake_data['latitude'], earthquake_data['longitude'], bins=50, cmap='YlGnBu')

# Add a colorbar to the plot
plt.colorbar()

# Set the title and axis labels
plt.title('Earthquake Heatmap')
plt.xlabel('Latitude')
plt.ylabel('Longitude')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
get_cmap()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_cmap()
#
# NameError: name 'get_cmap' is not defined

# %%
import matplotlib.pyplot as plt

# Latitude and Longitude data 
latitude = earthquake_data['latitude']  # List of latitude values
longitude = earthquake_data['longitude']  # List of longitude values

# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(longitude, latitude, color='red', marker='o', s=10)  # s is the size of markers
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Earthquake Epicenters Scatter Plot')
plt.grid(True)
plt.show()
