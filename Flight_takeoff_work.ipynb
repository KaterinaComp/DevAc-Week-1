# %%
## Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
## getting data

flight_data = pd.read_csv('Flight_takeoff.csv')
flight_data
# Out:
#        MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM DEST  \
# 0         11             1            5                B6   N828JB  CHS
# 1         11             1            5                B6   N992JB  LAX
# 2         11             1            5                B6   N959JB  FLL
# 3         11             1            5                B6   N999JQ  MCO
# 4         11             1            5                DL   N880DN  ATL
# ...      ...           ...          ...               ...      ...  ...
# 28815      1            31            5                B6   N216JB  ORH
# 28816      1            31            5                AA   N104NN  BOS
# 28817      1            31            5                AS   N581AS  SEA
# 28818      1            31            5                B6   N957JB  SJU
# 28819      1            31            5                B6   N958JB  BQN
#
#        DEP_DELAY  CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  ...  Dew Point  \
# ...

# %%
flight_data.head(10)
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM DEST  \
# 0     11             1            5                B6   N828JB  CHS
# 1     11             1            5                B6   N992JB  LAX
# 2     11             1            5                B6   N959JB  FLL
# 3     11             1            5                B6   N999JQ  MCO
# 4     11             1            5                DL   N880DN  ATL
# 5     11             1            5                AA   N983NN  ORD
# 6     11             1            5                AA   N107NN  LAX
# 7     11             1            5                B6   N274JB  BUF
# 8     11             1            5                B6   N663JB  LGB
# 9     11             1            5                B6   N283JB  FLL
#
#    DEP_DELAY  CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  ...  Dew Point  Humidity  \
# 0         -1               124       636        324  ...         34        58
# ...

# %%
## data types

flight_data.dtypes
# Out:
# MONTH                  int64
# DAY_OF_MONTH           int64
# DAY_OF_WEEK            int64
# OP_UNIQUE_CARRIER     object
# TAIL_NUM              object
# DEST                  object
# DEP_DELAY              int64
# CRS_ELAPSED_TIME       int64
# DISTANCE               int64
# CRS_DEP_M              int64
# DEP_TIME_M             int64
# CRS_ARR_M              int64
# Temperature            int64
# Dew Point             object
# Humidity               int64
# Wind                  object
# Wind Speed             int64
# Wind Gust              int64
# Pressure             float64
# Condition             object
# sch_dep                int64
# sch_arr                int64
# TAXI_OUT               int64
# dtype: object

# %%
## Check for null values

flight_data.isnull().sum()
# Out:
# MONTH                0
# DAY_OF_MONTH         0
# DAY_OF_WEEK          0
# OP_UNIQUE_CARRIER    0
# TAIL_NUM             0
# DEST                 0
# DEP_DELAY            0
# CRS_ELAPSED_TIME     0
# DISTANCE             0
# CRS_DEP_M            0
# DEP_TIME_M           0
# CRS_ARR_M            0
# Temperature          0
# Dew Point            0
# Humidity             0
# Wind                 2
# Wind Speed           0
# Wind Gust            0
# Pressure             0
# Condition            0
# sch_dep              0
# sch_arr              0
# TAXI_OUT             0
# dtype: int64

# %%
# Identify rows with missing values in the "WIND" column
missing_rows = flight_data[flight_data['Wind'].isnull()]
missing_rows
# Out:
#        MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM DEST  \
# 15156     12            19            4                B6   N648JB  FLL
# 15157     12            19            4                9E   N136EV  PWM
#
#        DEP_DELAY  CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  ...  Dew Point  \
# 15156         60               189      1069       1275  ...         10
# 15157          3                83       273       1349  ...         10
#
#        Humidity  Wind Wind Speed  Wind Gust Pressure      Condition  sch_dep  \
# 15156        55   NaN          0          0    30.42  Mostly Cloudy       21
# 15157        55   NaN          0          0    30.42  Mostly Cloudy       21
#
#        sch_arr TAXI_OUT
# 15156       33       41
# 15157       33       40
#
# [2 rows x 23 columns]

# %%
# Change specific rows with NaN values in 'Wind' column to 'W'
specific_rows = [15156, 15157]
for row_index in specific_rows:
    if pd.isnull(flight_data.at[row_index, 'Wind']):
        flight_data.at[row_index, 'Wind'] = 'W'

# %%
flight_data.isnull().sum()
# Out:
# MONTH                0
# DAY_OF_MONTH         0
# DAY_OF_WEEK          0
# OP_UNIQUE_CARRIER    0
# TAIL_NUM             0
# DEST                 0
# DEP_DELAY            0
# CRS_ELAPSED_TIME     0
# DISTANCE             0
# CRS_DEP_M            0
# DEP_TIME_M           0
# CRS_ARR_M            0
# Temperature          0
# Dew Point            0
# Humidity             0
# Wind                 0
# Wind Speed           0
# Wind Gust            0
# Pressure             0
# Condition            0
# sch_dep              0
# sch_arr              0
# TAXI_OUT             0
# dtype: int64

# %%
# Save the modified dataset
flight_data.to_csv("modified_dataset.csv", index=False)

# %%
flight_data.shape
# Out:
# (28820, 23)

# %%
## Drop unnecassary columns
flight_data.drop(columns='TAIL_NUM', inplace=True)
flight_data.head()
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER DEST  DEP_DELAY  \
# 0     11             1            5                B6  CHS         -1
# 1     11             1            5                B6  LAX         -7
# 2     11             1            5                B6  FLL         40
# 3     11             1            5                B6  MCO         -2
# 4     11             1            5                DL  ATL         -4
#
#    CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  DEP_TIME_M  ...  Dew Point  \
# 0               124       636        324         323  ...         34
# 1               371      2475        340         333  ...         34
# 2               181      1069        301         341  ...         34
# 3               168       944        345         343  ...         34
# 4               139       760        360         356  ...         32
#
#    Humidity Wind  Wind Speed Wind Gust  Pressure     Condition  sch_dep  \
# ...

# %%
##  LabelEncoder is used to transform categorical variables into numerical labels, which can be more easily used in machine learning algorithms that require numerical inputs. 
## Each unique category in the original categorical variable is assigned a unique integer label.

from sklearn.preprocessing import LabelEncoder as LE

flight_data.sch_dep=LE().fit_transform(flight_data.sch_dep)
flight_data.Condition =LE().fit_transform(flight_data.Condition)
flight_data.Wind =LE().fit_transform(flight_data.Wind.astype(str))
flight_data.DEST=LE().fit_transform(flight_data.DEST)
flight_data.OP_UNIQUE_CARRIER=LE().fit_transform(flight_data.OP_UNIQUE_CARRIER)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Check correlation
plt.figure(figsize=(12,8))
sns.heatmap(flight_data.corr(), annot=True, annot_kws={'size': 8})
# Out:
# <Axes: >

# %%
## Drop unnecassary columns

flight_data.drop(columns=['CRS_ELAPSED_TIME', 'CRS_DEP_M', 'Dew Point', 'Wind Gust'], inplace=True)
flight_data.head()
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK  OP_UNIQUE_CARRIER  DEST  DEP_DELAY  \
# 0     11             1            5                  3    10         -1
# 1     11             1            5                  3    28         -7
# 2     11             1            5                  3    20         40
# 3     11             1            5                  3    30         -2
# 4     11             1            5                  4     1         -4
#
#    DISTANCE  DEP_TIME_M  CRS_ARR_M  Temperature  Humidity  Wind  Wind Speed  \
# 0       636         323        448           48        58    15          25
# 1      2475         333        531           48        58    15          25
# 2      1069         341        482           48        58    15          25
# 3       944         343        513           48        58    15          25
# 4       760         356        499           46        58    15          24
#
#    Pressure  Condition  sch_dep  sch_arr  TAXI_OUT
# ...

# %%
# Save the modified dataset
flight_data.to_csv("modified_dataset.csv", index=False)

# %%
## Independent features

##X = flight_data[['DAY_OF_WEEK','DEST','DEP_DELAY','CRS_ARR_M','Temperature', 'Humidity','Wind', 'Wind Speed','Pressure', 'Condition', 'sch_dep', 'sch_arr']]
##X.head()

# %%
## Independent features and dependent features

## select the needed data points for independent and dependent variables
##data.iloc[:, 3]: This part of the code selects all rows (:) from the DataFrame data and the 4th column (index 3) using integer-based indexing with .iloc[]. 
##This operation extracts a one-dimensional array (technically a pandas Series) containing the values from the specified column.

X = flight_data.iloc[:,:-1]. values.reshape(-1,1)  ## INDEPENDENT FEATURE
y = flight_data.iloc[:, 17] ## DEPENDENT FEATURE

# %%
X
# Out:
# array([[11.],
#        [ 1.],
#        [ 5.],
#        ...,
#        [ 0.],
#        [19.],
#        [23.]])

# %%
y
# Out:
# 0        14
# 1        15
# 2        22
# 3        12
# 4        13
#          ..
# 28815    19
# 28816    22
# 28817    21
# 28818    13
# 28819    15
# Name: TAXI_OUT, Length: 28820, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, RidgeCV
from sklearn.model_selection import RepeatedKFold

# %%
##  Train test split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
linreg = LinearRegression()
model = linreg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 3
#       1 ##  Train test split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#       4 linreg = LinearRegression()
#       5 model = linreg.fit(X_train, y_train)
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42 )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42 )
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
# ...

# %%
## Standardisation

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 5
#       3 from sklearn.preprocessing import StandardScaler
#       4 scaler = StandardScaler()
# ----> 5 X_train = scaler.fit_transform(X_train)
#       6 X_test = scaler.transform(X_test)
#       7 X_train
#
# NameError: name 'X_train' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42 )
#
# File c:\Users\kater\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 5
#       3 from sklearn.preprocessing import StandardScaler
#       4 scaler = StandardScaler()
# ----> 5 X_train = scaler.fit_transform(X_train)
#       6 X_test = scaler.transform(X_test)
#       7 X_train
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Define preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Fit and transform preprocessing steps on training data
x_train_preprocessed = preprocessor.fit_transform(x_train)

# Transform preprocessing steps on test data
x_test_preprocessed = preprocessor.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[165], line 7
#       2 from sklearn.compose import ColumnTransformer
#       4 # Define preprocessing steps
#       5 preprocessor = ColumnTransformer(
#       6     transformers=[
# ----> 7         ('num', StandardScaler(), numeric_features),
#       8         ('cat', OneHotEncoder(), categorical_features)
#       9     ])
#      11 # Fit and transform preprocessing steps on training data
#      12 x_train_preprocessed = preprocessor.fit_transform(x_train)
#
# NameError: name 'numeric_features' is not defined
